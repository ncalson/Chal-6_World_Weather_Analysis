# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description":description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | camacha
# Processing Record 2 of Set 1 | cherskiy
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | san lorenzo
# Processing Record 5 of Set 1 | bara
# Processing Record 6 of Set 1 | srednekolymsk
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | ostrovnoy
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | asfi
# Processing Record 19 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 1 | maymyo
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | altea
# Processing Record 23 of Set 1 | san quintin
# Processing Record 24 of Set 1 | qibili
# City not found. Skipping...
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | phonhong
# Processing Record 28 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 1 | san cristobal
# Processing Record 32 of Set 1 | lakes entrance
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | skibbereen
# Processing Record 36 of Set 1 | ponta do sol
# Processing Record 37 of Set 1 | longyearbyen
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | svetlogorsk
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | memari
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | sorland
# Processing Record 47 of Set 1 | kloulklubed
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | domna
# Processing Record 50 of Set 1 | aloleng
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | bjornevatn
# Processing Record 4 of Set 2 | havoysund
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | itoman
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | rawson
# Processing Record 9 of Set 2 | labuhan
# Processing Record 10 of Set 2 | miraflores
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | saint-paul
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | esperance
# Processing Record 15 of Set 2 | tasiilaq
# Processing Record 16 of Set 2 | colares
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | westervoort
# Processing Record 19 of Set 2 | osa
# Processing Record 20 of Set 2 | necochea
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | cayenne
# Processing Record 23 of Set 2 | cabo san lucas
# Processing Record 24 of Set 2 | arman
# Processing Record 25 of Set 2 | deputatskiy
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | mangan
# Processing Record 28 of Set 2 | vostok
# Processing Record 29 of Set 2 | half moon bay
# Processing Record 30 of Set 2 | ushuaia
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | kabo
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | saint-francois
# Processing Record 36 of Set 2 | chaohu
# Processing Record 37 of Set 2 | nome
# Processing Record 38 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 2 | burnie
# Processing Record 40 of Set 2 | tsiroanomandidy
# Processing Record 41 of Set 2 | klaksvik
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | mokhsogollokh
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | kozlovka
# Processing Record 47 of Set 2 | bajo baudo
# City not found. Skipping...
# Processing Record 48 of Set 2 | dwarka
# Processing Record 49 of Set 2 | flin flon
# Processing Record 50 of Set 2 | cervo
# Processing Record 1 of Set 3 | northam
# Processing Record 2 of Set 3 | mehamn
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | fatwa
# Processing Record 5 of Set 3 | high level
# Processing Record 6 of Set 3 | vanimo
# Processing Record 7 of Set 3 | wamba
# Processing Record 8 of Set 3 | togur
# Processing Record 9 of Set 3 | nago
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | joetsu
# Processing Record 13 of Set 3 | bar bigha
# Processing Record 14 of Set 3 | vestmannaeyjar
# Processing Record 15 of Set 3 | mirnyy
# Processing Record 16 of Set 3 | villa rica
# Processing Record 17 of Set 3 | ancud
# Processing Record 18 of Set 3 | tuatapere
# Processing Record 19 of Set 3 | dunkirk
# Processing Record 20 of Set 3 | merauke
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | byron bay
# Processing Record 23 of Set 3 | dekar
# Processing Record 24 of Set 3 | bluff
# Processing Record 25 of Set 3 | tiznit
# Processing Record 26 of Set 3 | sao joao da barra
# Processing Record 27 of Set 3 | amahai
# Processing Record 28 of Set 3 | thompson
# Processing Record 29 of Set 3 | kiruna
# Processing Record 30 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | dongying
# Processing Record 33 of Set 3 | grindavik
# Processing Record 34 of Set 3 | isangel
# Processing Record 35 of Set 3 | manicore
# Processing Record 36 of Set 3 | kavaratti
# Processing Record 37 of Set 3 | lichuan
# Processing Record 38 of Set 3 | ixtapa
# Processing Record 39 of Set 3 | lar
# Processing Record 40 of Set 3 | cape coast
# Processing Record 41 of Set 3 | kattivakkam
# Processing Record 42 of Set 3 | ilukste
# Processing Record 43 of Set 3 | naze
# Processing Record 44 of Set 3 | dekoa
# City not found. Skipping...
# Processing Record 45 of Set 3 | manokwari
# Processing Record 46 of Set 3 | rundu
# Processing Record 47 of Set 3 | usinsk
# Processing Record 48 of Set 3 | loreto
# Processing Record 49 of Set 3 | kisangani
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 4 | whitehorse
# Processing Record 3 of Set 4 | amapa
# Processing Record 4 of Set 4 | airai
# Processing Record 5 of Set 4 | east london
# Processing Record 6 of Set 4 | bethel
# Processing Record 7 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 4 | kungurtug
# Processing Record 9 of Set 4 | morgan city
# Processing Record 10 of Set 4 | aksehir
# Processing Record 11 of Set 4 | sitka
# Processing Record 12 of Set 4 | kampot
# Processing Record 13 of Set 4 | mizan teferi
# Processing Record 14 of Set 4 | atuona
# Processing Record 15 of Set 4 | cockburn town
# Processing Record 16 of Set 4 | bubaque
# Processing Record 17 of Set 4 | fortuna
# Processing Record 18 of Set 4 | tabory
# Processing Record 19 of Set 4 | kaitangata
# Processing Record 20 of Set 4 | kawalu
# Processing Record 21 of Set 4 | blagoyevo
# Processing Record 22 of Set 4 | iquitos
# Processing Record 23 of Set 4 | praia da vitoria
# Processing Record 24 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 25 of Set 4 | alofi
# Processing Record 26 of Set 4 | bathsheba
# Processing Record 27 of Set 4 | batemans bay
# Processing Record 28 of Set 4 | kudahuvadhoo
# Processing Record 29 of Set 4 | pochutla
# Processing Record 30 of Set 4 | waipawa
# Processing Record 31 of Set 4 | butembo
# Processing Record 32 of Set 4 | puerto ayacucho
# Processing Record 33 of Set 4 | tighnabruaich
# Processing Record 34 of Set 4 | progreso
# Processing Record 35 of Set 4 | faanui
# Processing Record 36 of Set 4 | winnemucca
# Processing Record 37 of Set 4 | tura
# Processing Record 38 of Set 4 | kirakira
# Processing Record 39 of Set 4 | arraial do cabo
# Processing Record 40 of Set 4 | bantry
# Processing Record 41 of Set 4 | clyde river
# Processing Record 42 of Set 4 | hobyo
# Processing Record 43 of Set 4 | avera
# Processing Record 44 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 4 | sao felix do xingu
# Processing Record 46 of Set 4 | lagos
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | inirida
# Processing Record 49 of Set 4 | prosvet
# Processing Record 50 of Set 4 | jalu
# Processing Record 1 of Set 5 | pangody
# Processing Record 2 of Set 5 | vardo
# Processing Record 3 of Set 5 | torbay
# Processing Record 4 of Set 5 | tashla
# Processing Record 5 of Set 5 | lesnoy
# Processing Record 6 of Set 5 | sereflikochisar
# Processing Record 7 of Set 5 | borba
# Processing Record 8 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 5 | codrington
# Processing Record 10 of Set 5 | chara
# Processing Record 11 of Set 5 | saint george
# Processing Record 12 of Set 5 | chokurdakh
# Processing Record 13 of Set 5 | berlevag
# Processing Record 14 of Set 5 | salalah
# Processing Record 15 of Set 5 | dongobesh
# Processing Record 16 of Set 5 | isfana
# Processing Record 17 of Set 5 | knysna
# Processing Record 18 of Set 5 | aracati
# Processing Record 19 of Set 5 | shahrud
# Processing Record 20 of Set 5 | msanga
# Processing Record 21 of Set 5 | batie
# Processing Record 22 of Set 5 | kalabo
# Processing Record 23 of Set 5 | chapais
# Processing Record 24 of Set 5 | khatanga
# Processing Record 25 of Set 5 | caravelas
# Processing Record 26 of Set 5 | macapa
# Processing Record 27 of Set 5 | denpasar
# Processing Record 28 of Set 5 | kulhudhuffushi
# Processing Record 29 of Set 5 | jawad
# Processing Record 30 of Set 5 | kruisfontein
# Processing Record 31 of Set 5 | chulym
# Processing Record 32 of Set 5 | plettenberg bay
# Processing Record 33 of Set 5 | sao jose da coroa grande
# Processing Record 34 of Set 5 | ponta delgada
# Processing Record 35 of Set 5 | kouqian
# Processing Record 36 of Set 5 | pangnirtung
# Processing Record 37 of Set 5 | warrington
# Processing Record 38 of Set 5 | meadow lake
# Processing Record 39 of Set 5 | bengkulu
# Processing Record 40 of Set 5 | roma
# Processing Record 41 of Set 5 | katsuura
# Processing Record 42 of Set 5 | kavieng
# Processing Record 43 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 5 | ilulissat
# Processing Record 45 of Set 5 | kargasok
# Processing Record 46 of Set 5 | mbandaka
# Processing Record 47 of Set 5 | aran
# Processing Record 48 of Set 5 | talara
# Processing Record 49 of Set 5 | laguna
# Processing Record 50 of Set 5 | richards bay
# Processing Record 1 of Set 6 | vishnyakovskiye dachi
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | tupik
# Processing Record 4 of Set 6 | bayonet point
# Processing Record 5 of Set 6 | henties bay
# Processing Record 6 of Set 6 | hasaki
# Processing Record 7 of Set 6 | qandala
# Processing Record 8 of Set 6 | port augusta
# Processing Record 9 of Set 6 | rassvet
# Processing Record 10 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 11 of Set 6 | mapastepec
# Processing Record 12 of Set 6 | vadu izei
# Processing Record 13 of Set 6 | hambantota
# Processing Record 14 of Set 6 | viedma
# Processing Record 15 of Set 6 | solnechnoye
# Processing Record 16 of Set 6 | zheleznodorozhnyy
# Processing Record 17 of Set 6 | gunzenhausen
# Processing Record 18 of Set 6 | alyangula
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | lorengau
# Processing Record 21 of Set 6 | oranjemund
# Processing Record 22 of Set 6 | kondinskoye
# Processing Record 23 of Set 6 | makakilo city
# Processing Record 24 of Set 6 | taunggyi
# Processing Record 25 of Set 6 | aneho
# Processing Record 26 of Set 6 | banff
# Processing Record 27 of Set 6 | vanavara
# Processing Record 28 of Set 6 | san juan
# Processing Record 29 of Set 6 | alice springs
# Processing Record 30 of Set 6 | kollegal
# Processing Record 31 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 6 | severnyy
# Processing Record 33 of Set 6 | wichita falls
# Processing Record 34 of Set 6 | kirkwall
# Processing Record 35 of Set 6 | nouadhibou
# Processing Record 36 of Set 6 | imbituba
# Processing Record 37 of Set 6 | guerrero negro
# Processing Record 38 of Set 6 | ambovombe
# Processing Record 39 of Set 6 | neiafu
# Processing Record 40 of Set 6 | mount gambier
# Processing Record 41 of Set 6 | baijiantan
# Processing Record 42 of Set 6 | husavik
# Processing Record 43 of Set 6 | koppa
# Processing Record 44 of Set 6 | ilebo
# Processing Record 45 of Set 6 | shache
# Processing Record 46 of Set 6 | port hardy
# Processing Record 47 of Set 6 | snezhnogorsk
# Processing Record 48 of Set 6 | mar del plata
# Processing Record 49 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 50 of Set 6 | ulladulla
# Processing Record 1 of Set 7 | luganville
# Processing Record 2 of Set 7 | pechenga
# Processing Record 3 of Set 7 | camaguey
# Processing Record 4 of Set 7 | ust-maya
# Processing Record 5 of Set 7 | nacogdoches
# Processing Record 6 of Set 7 | rafaela
# Processing Record 7 of Set 7 | korla
# Processing Record 8 of Set 7 | yar-sale
# Processing Record 9 of Set 7 | hofn
# Processing Record 10 of Set 7 | dongli
# Processing Record 11 of Set 7 | guiglo
# Processing Record 12 of Set 7 | prince rupert
# Processing Record 13 of Set 7 | thinadhoo
# Processing Record 14 of Set 7 | saint-leu
# Processing Record 15 of Set 7 | dicabisagan
# Processing Record 16 of Set 7 | salinopolis
# Processing Record 17 of Set 7 | conceicao da barra
# Processing Record 18 of Set 7 | zyryanka
# Processing Record 19 of Set 7 | marienburg
# Processing Record 20 of Set 7 | tabarqah
# City not found. Skipping...
# Processing Record 21 of Set 7 | bilibino
# Processing Record 22 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 7 | spencer
# Processing Record 24 of Set 7 | bemidji
# Processing Record 25 of Set 7 | rio grande
# Processing Record 26 of Set 7 | comodoro rivadavia
# Processing Record 27 of Set 7 | zhanakorgan
# Processing Record 28 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 7 | otane
# Processing Record 30 of Set 7 | waddan
# Processing Record 31 of Set 7 | walvis bay
# Processing Record 32 of Set 7 | iqaluit
# Processing Record 33 of Set 7 | vila velha
# Processing Record 34 of Set 7 | victoria
# Processing Record 35 of Set 7 | vao
# Processing Record 36 of Set 7 | padang
# Processing Record 37 of Set 7 | wajima
# Processing Record 38 of Set 7 | cidreira
# Processing Record 39 of Set 7 | santa paula
# Processing Record 40 of Set 7 | new richmond
# Processing Record 41 of Set 7 | zatoka
# Processing Record 42 of Set 7 | kharan
# Processing Record 43 of Set 7 | namibe
# Processing Record 44 of Set 7 | moree
# Processing Record 45 of Set 7 | changtu
# Processing Record 46 of Set 7 | marfino
# Processing Record 47 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 7 | norman wells
# Processing Record 49 of Set 7 | huarmey
# Processing Record 50 of Set 7 | fairbanks
# Processing Record 1 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 8 | hastings
# Processing Record 3 of Set 8 | bestobe
# Processing Record 4 of Set 8 | maragogi
# Processing Record 5 of Set 8 | beringovskiy
# Processing Record 6 of Set 8 | tazovskiy
# Processing Record 7 of Set 8 | carutapera
# Processing Record 8 of Set 8 | hervey bay
# Processing Record 9 of Set 8 | sao filipe
# Processing Record 10 of Set 8 | gouyave
# Processing Record 11 of Set 8 | virginia beach
# Processing Record 12 of Set 8 | beinamar
# Processing Record 13 of Set 8 | marawi
# Processing Record 14 of Set 8 | santo antonio do ica
# Processing Record 15 of Set 8 | puerto del rosario
# Processing Record 16 of Set 8 | toamasina
# Processing Record 17 of Set 8 | touros
# Processing Record 18 of Set 8 | udachnyy
# Processing Record 19 of Set 8 | timra
# Processing Record 20 of Set 8 | hami
# Processing Record 21 of Set 8 | lagoa
# Processing Record 22 of Set 8 | dubrovnik
# Processing Record 23 of Set 8 | fernandina beach
# Processing Record 24 of Set 8 | kahului
# Processing Record 25 of Set 8 | komsomolskiy
# Processing Record 26 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 8 | sechura
# Processing Record 28 of Set 8 | itarema
# Processing Record 29 of Set 8 | ocosingo
# Processing Record 30 of Set 8 | haines junction
# Processing Record 31 of Set 8 | eureka
# Processing Record 32 of Set 8 | muros
# Processing Record 33 of Set 8 | agropoli
# Processing Record 34 of Set 8 | pointe-noire
# Processing Record 35 of Set 8 | phan thiet
# Processing Record 36 of Set 8 | kichera
# Processing Record 37 of Set 8 | kuytun
# Processing Record 38 of Set 8 | palmer
# Processing Record 39 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 40 of Set 8 | teya
# Processing Record 41 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 8 | mareeba
# Processing Record 43 of Set 8 | vitim
# Processing Record 44 of Set 8 | rawlins
# Processing Record 45 of Set 8 | bambanglipuro
# Processing Record 46 of Set 8 | minab
# Processing Record 47 of Set 8 | samarai
# Processing Record 48 of Set 8 | tezu
# Processing Record 49 of Set 8 | kerman
# Processing Record 50 of Set 8 | pevek
# Processing Record 1 of Set 9 | chimbote
# Processing Record 2 of Set 9 | marsa matruh
# Processing Record 3 of Set 9 | male
# Processing Record 4 of Set 9 | namatanai
# Processing Record 5 of Set 9 | port lincoln
# Processing Record 6 of Set 9 | kununurra
# Processing Record 7 of Set 9 | lompoc
# Processing Record 8 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 9 | salta
# Processing Record 10 of Set 9 | kirando
# Processing Record 11 of Set 9 | kamalapuram
# Processing Record 12 of Set 9 | narsaq
# Processing Record 13 of Set 9 | ardakan
# Processing Record 14 of Set 9 | madang
# Processing Record 15 of Set 9 | oudtshoorn
# Processing Record 16 of Set 9 | stelle
# Processing Record 17 of Set 9 | kushmurun
# Processing Record 18 of Set 9 | ola
# Processing Record 19 of Set 9 | san policarpo
# Processing Record 20 of Set 9 | yomitan
# City not found. Skipping...
# Processing Record 21 of Set 9 | meulaboh
# Processing Record 22 of Set 9 | dvinskoy
# Processing Record 23 of Set 9 | curup
# Processing Record 24 of Set 9 | oyabe
# Processing Record 25 of Set 9 | taltal
# Processing Record 26 of Set 9 | ramnagar
# Processing Record 27 of Set 9 | galesong
# Processing Record 28 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 29 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 9 | souillac
# Processing Record 33 of Set 9 | calvinia
# Processing Record 34 of Set 9 | carson city
# Processing Record 35 of Set 9 | las vegas
# Processing Record 36 of Set 9 | saint-pierre
# Processing Record 37 of Set 9 | sistranda
# Processing Record 38 of Set 9 | belmonte
# Processing Record 39 of Set 9 | big spring
# Processing Record 40 of Set 9 | bafra
# Processing Record 41 of Set 9 | ammon
# Processing Record 42 of Set 9 | lavrentiya
# Processing Record 43 of Set 9 | taoudenni
# Processing Record 44 of Set 9 | aykhal
# Processing Record 45 of Set 9 | atikokan
# Processing Record 46 of Set 9 | karasjok
# Processing Record 47 of Set 9 | vertientes
# Processing Record 48 of Set 9 | palmas
# Processing Record 49 of Set 9 | nichinan
# Processing Record 50 of Set 9 | weyburn
# Processing Record 1 of Set 10 | wenling
# Processing Record 2 of Set 10 | jablah
# Processing Record 3 of Set 10 | mamallapuram
# Processing Record 4 of Set 10 | vaitape
# Processing Record 5 of Set 10 | port-gentil
# Processing Record 6 of Set 10 | nortelandia
# Processing Record 7 of Set 10 | zhigansk
# Processing Record 8 of Set 10 | gambo
# Processing Record 9 of Set 10 | bukama
# Processing Record 10 of Set 10 | raudeberg
# Processing Record 11 of Set 10 | vagur
# Processing Record 12 of Set 10 | bagdarin
# Processing Record 13 of Set 10 | payo
# Processing Record 14 of Set 10 | hornostayivka
# Processing Record 15 of Set 10 | olinda
# Processing Record 16 of Set 10 | sipe sipe
# Processing Record 17 of Set 10 | san carlos
# Processing Record 18 of Set 10 | gat
# Processing Record 19 of Set 10 | honningsvag
# Processing Record 20 of Set 10 | havelock
# Processing Record 21 of Set 10 | la ronge
# Processing Record 22 of Set 10 | joacaba
# Processing Record 23 of Set 10 | dingle
# Processing Record 24 of Set 10 | victoria point
# Processing Record 25 of Set 10 | fare
# Processing Record 26 of Set 10 | randolph
# Processing Record 27 of Set 10 | nantucket
# Processing Record 28 of Set 10 | liuzhou
# Processing Record 29 of Set 10 | almeria
# Processing Record 30 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 10 | saint-augustin
# Processing Record 32 of Set 10 | aasiaat
# Processing Record 33 of Set 10 | santa rosa
# Processing Record 34 of Set 10 | kidodi
# Processing Record 35 of Set 10 | balkhash
# Processing Record 36 of Set 10 | egvekinot
# Processing Record 37 of Set 10 | paraiso
# Processing Record 38 of Set 10 | bollnas
# Processing Record 39 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 10 | el tigre
# Processing Record 41 of Set 10 | nikolayevsk-na-amure
# Processing Record 42 of Set 10 | opuwo
# Processing Record 43 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 10 | mount isa
# Processing Record 45 of Set 10 | borogontsy
# Processing Record 46 of Set 10 | sokolniki
# Processing Record 47 of Set 10 | marzuq
# Processing Record 48 of Set 10 | riyadh
# Processing Record 49 of Set 10 | cururupu
# Processing Record 50 of Set 10 | fuling
# Processing Record 1 of Set 11 | mackay
# Processing Record 2 of Set 11 | khani
# Processing Record 3 of Set 11 | gotsu
# Processing Record 4 of Set 11 | reconquista
# Processing Record 5 of Set 11 | saint-joseph
# Processing Record 6 of Set 11 | gallup
# Processing Record 7 of Set 11 | ahipara
# Processing Record 8 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 9 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 10 of Set 11 | bulgan
# Processing Record 11 of Set 11 | yatou
# Processing Record 12 of Set 11 | unjha
# Processing Record 13 of Set 11 | forio
# Processing Record 14 of Set 11 | karur
# Processing Record 15 of Set 11 | neverkino
# Processing Record 16 of Set 11 | te anau
# Processing Record 17 of Set 11 | heyang
# Processing Record 18 of Set 11 | sovetskiy
# Processing Record 19 of Set 11 | suleja
# Processing Record 20 of Set 11 | broome
# Processing Record 21 of Set 11 | benavente
# Processing Record 22 of Set 11 | kota tinggi
# Processing Record 23 of Set 11 | sheridan
# Processing Record 24 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 11 | bairiki
# Processing Record 26 of Set 11 | sinnamary
# Processing Record 27 of Set 11 | faya
# Processing Record 28 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 11 | redlands
# Processing Record 30 of Set 11 | dakar
# Processing Record 31 of Set 11 | mogadishu
# Processing Record 32 of Set 11 | kaeo
# Processing Record 33 of Set 11 | ishigaki
# Processing Record 34 of Set 11 | al
# City not found. Skipping...
# Processing Record 35 of Set 11 | mahibadhoo
# Processing Record 36 of Set 11 | dunedin
# Processing Record 37 of Set 11 | victor harbor
# Processing Record 38 of Set 11 | baykit
# Processing Record 39 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 40 of Set 11 | mingguang
# Processing Record 41 of Set 11 | bima
# Processing Record 42 of Set 11 | santa marta
# Processing Record 43 of Set 11 | waingapu
# Processing Record 44 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 11 | santa lucia
# Processing Record 46 of Set 11 | ugoofaaru
# Processing Record 47 of Set 11 | kostrzyn
# Processing Record 48 of Set 11 | nabire
# Processing Record 49 of Set 11 | poso
# Processing Record 50 of Set 11 | wegorzewo
# Processing Record 1 of Set 12 | lopatino
# Processing Record 2 of Set 12 | trinidad
# Processing Record 3 of Set 12 | bud
# Processing Record 4 of Set 12 | karratha
# Processing Record 5 of Set 12 | biak
# Processing Record 6 of Set 12 | hualmay
# Processing Record 7 of Set 12 | barrhead
# Processing Record 8 of Set 12 | vung tau
# Processing Record 9 of Set 12 | tawau
# Processing Record 10 of Set 12 | corowa
# Processing Record 11 of Set 12 | ondjiva
# Processing Record 12 of Set 12 | delano
# Processing Record 13 of Set 12 | espanola
# Processing Record 14 of Set 12 | la tuque
# Processing Record 15 of Set 12 | pemba
# Processing Record 16 of Set 12 | razam
# Processing Record 17 of Set 12 | stephenville
# Processing Record 18 of Set 12 | camacupa
# Processing Record 19 of Set 12 | mitsamiouli
# Processing Record 20 of Set 12 | atambua
# Processing Record 21 of Set 12 | kapit
# Processing Record 22 of Set 12 | fugen
# Processing Record 23 of Set 12 | belomorsk
# Processing Record 24 of Set 12 | orchard homes
# Processing Record 25 of Set 12 | maniitsoq
# Processing Record 26 of Set 12 | santa ana
# Processing Record 27 of Set 12 | ayios kirikos
# City not found. Skipping...
# Processing Record 28 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 29 of Set 12 | bristol
# Processing Record 30 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 12 | coquimbo
# Processing Record 32 of Set 12 | kalmunai
# Processing Record 33 of Set 12 | san patricio
# Processing Record 34 of Set 12 | salym
# Processing Record 35 of Set 12 | beihai
# Processing Record 36 of Set 12 | frederick
# Processing Record 37 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 12 | tromso
# Processing Record 39 of Set 12 | san pedro
# Processing Record 40 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 12 | letnyaya stavka
# Processing Record 42 of Set 12 | rio do sul
# Processing Record 43 of Set 12 | troy
# Processing Record 44 of Set 12 | melbu
# Processing Record 45 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 12 | buala
# Processing Record 47 of Set 12 | plouzane
# Processing Record 48 of Set 12 | sola
# Processing Record 49 of Set 12 | puerto asis
# Processing Record 50 of Set 12 | shakhtne
# Processing Record 1 of Set 13 | margate
# Processing Record 2 of Set 13 | gizo
# Processing Record 3 of Set 13 | uvat
# Processing Record 4 of Set 13 | bousso
# Processing Record 5 of Set 13 | rehoboth
# Processing Record 6 of Set 13 | shakhtinsk
# Processing Record 7 of Set 13 | tateyama
# Processing Record 8 of Set 13 | abu samrah
# Processing Record 9 of Set 13 | sisimiut
# Processing Record 10 of Set 13 | coldstream
# Processing Record 11 of Set 13 | cazaje
# City not found. Skipping...
# Processing Record 12 of Set 13 | woodstock
# Processing Record 13 of Set 13 | pastavy
# Processing Record 14 of Set 13 | ariyalur
# Processing Record 15 of Set 13 | atar
# Processing Record 16 of Set 13 | santiago del estero
# Processing Record 17 of Set 13 | dabeiba
# Processing Record 18 of Set 13 | sapele
# Processing Record 19 of Set 13 | raga
# Processing Record 20 of Set 13 | quang ngai
# Processing Record 21 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 13 | giehun
# Processing Record 23 of Set 13 | hovd
# Processing Record 24 of Set 13 | malanje
# Processing Record 25 of Set 13 | adrar
# Processing Record 26 of Set 13 | coihaique
# Processing Record 27 of Set 13 | miranda
# Processing Record 28 of Set 13 | theunissen
# Processing Record 29 of Set 13 | santa maria
# Processing Record 30 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 13 | broken hill
# Processing Record 32 of Set 13 | novoagansk
# Processing Record 33 of Set 13 | kandrian
# Processing Record 34 of Set 13 | bari
# Processing Record 35 of Set 13 | corner brook
# Processing Record 36 of Set 13 | ayan
# Processing Record 37 of Set 13 | hamilton
# Processing Record 38 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 13 | duluth
# Processing Record 40 of Set 13 | harper
# Processing Record 41 of Set 13 | poum
# Processing Record 42 of Set 13 | itanagar
# Processing Record 43 of Set 13 | ngunguru
# Processing Record 44 of Set 13 | sturgeon falls
# Processing Record 45 of Set 13 | sakaiminato
# Processing Record 46 of Set 13 | novaya igirma
# Processing Record 47 of Set 13 | sorong
# Processing Record 48 of Set 13 | angoram
# Processing Record 49 of Set 13 | lososina
# Processing Record 50 of Set 13 | lamu
# Processing Record 1 of Set 14 | baruun-urt
# Processing Record 2 of Set 14 | flinders
# Processing Record 3 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 14 | vilhena
# Processing Record 5 of Set 14 | vysha
# Processing Record 6 of Set 14 | nueve de julio
# Processing Record 7 of Set 14 | sao jose do belmonte
# Processing Record 8 of Set 14 | port macquarie
# Processing Record 9 of Set 14 | yulara
# Processing Record 10 of Set 14 | hun
# Processing Record 11 of Set 14 | nemuro
# Processing Record 12 of Set 14 | murdochville
# Processing Record 13 of Set 14 | zhangye
# Processing Record 14 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 15 of Set 14 | melilla
# Processing Record 16 of Set 14 | omboue
# Processing Record 17 of Set 14 | ambilobe
# Processing Record 18 of Set 14 | sobolevo
# Processing Record 19 of Set 14 | coahuayana
# Processing Record 20 of Set 14 | teberda
# Processing Record 21 of Set 14 | lumphat
# Processing Record 22 of Set 14 | auki
# Processing Record 23 of Set 14 | paragominas
# Processing Record 24 of Set 14 | spremberg
# Processing Record 25 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 14 | griffith
# Processing Record 27 of Set 14 | dickinson
# Processing Record 28 of Set 14 | maryborough
# Processing Record 29 of Set 14 | jacksonville
# Processing Record 30 of Set 14 | navalmoral de la mata
# Processing Record 31 of Set 14 | martapura
# Processing Record 32 of Set 14 | tuy hoa
# Processing Record 33 of Set 14 | paamiut
# Processing Record 34 of Set 14 | dalby
# Processing Record 35 of Set 14 | chegdomyn
# Processing Record 36 of Set 14 | umm lajj
# Processing Record 37 of Set 14 | cambara
# Processing Record 38 of Set 14 | soyo
# Processing Record 39 of Set 14 | xuddur
# Processing Record 40 of Set 14 | balkanabat
# Processing Record 41 of Set 14 | tacuati
# Processing Record 42 of Set 14 | la orilla
# Processing Record 43 of Set 14 | nelson bay
# Processing Record 44 of Set 14 | tautira
# Processing Record 45 of Set 14 | leningradskiy
# Processing Record 46 of Set 14 | yoichi
# Processing Record 47 of Set 14 | daru
# Processing Record 48 of Set 14 | zhongshu
# Processing Record 49 of Set 14 | birao
# Processing Record 50 of Set 14 | pohorelice
# Processing Record 1 of Set 15 | verkhnyaya inta
# Processing Record 2 of Set 15 | abnub
# Processing Record 3 of Set 15 | fort smith
# Processing Record 4 of Set 15 | bonavista
# Processing Record 5 of Set 15 | ballina
# Processing Record 6 of Set 15 | puerto baquerizo moreno
# Processing Record 7 of Set 15 | qaqortoq
# Processing Record 8 of Set 15 | saint leonard
# Processing Record 9 of Set 15 | pagudpud
# Processing Record 10 of Set 15 | kristiinankaupunki
# Processing Record 11 of Set 15 | oistins
# Processing Record 12 of Set 15 | katha
# City not found. Skipping...
# Processing Record 13 of Set 15 | tual
# Processing Record 14 of Set 15 | rabo de peixe
# Processing Record 15 of Set 15 | red bluff
# Processing Record 16 of Set 15 | mersing
# Processing Record 17 of Set 15 | saint anthony
# Processing Record 18 of Set 15 | navahrudak
# Processing Record 19 of Set 15 | taylorville
# Processing Record 20 of Set 15 | bonfim
# Processing Record 21 of Set 15 | lancaster
# Processing Record 22 of Set 15 | tessalit
# Processing Record 23 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 24 of Set 15 | anadyr
# Processing Record 25 of Set 15 | erzurum
# Processing Record 26 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 15 | kindu
# Processing Record 28 of Set 15 | mattru
# Processing Record 29 of Set 15 | sambava
# Processing Record 30 of Set 15 | luis correia
# Processing Record 31 of Set 15 | almenara
# Processing Record 32 of Set 15 | mana
# Processing Record 33 of Set 15 | tomatlan
# Processing Record 34 of Set 15 | vila franca do campo
# Processing Record 35 of Set 15 | north bend
# Processing Record 36 of Set 15 | fukue
# Processing Record 37 of Set 15 | mayo
# Processing Record 38 of Set 15 | xuchang
# Processing Record 39 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 15 | atherton
# Processing Record 41 of Set 15 | palasa
# Processing Record 42 of Set 15 | de aar
# Processing Record 43 of Set 15 | makokou
# Processing Record 44 of Set 15 | wingham
# Processing Record 45 of Set 15 | tadine
# Processing Record 46 of Set 15 | takoradi
# Processing Record 47 of Set 15 | banda aceh
# Processing Record 48 of Set 15 | aljezur
# Processing Record 49 of Set 15 | pakala
# Processing Record 50 of Set 15 | enzan
# Processing Record 1 of Set 16 | gurgan
# City not found. Skipping...
# Processing Record 2 of Set 16 | hornepayne
# Processing Record 3 of Set 16 | goure
# Processing Record 4 of Set 16 | nacala
# Processing Record 5 of Set 16 | erzin
# Processing Record 6 of Set 16 | najran
# Processing Record 7 of Set 16 | vadso
# Processing Record 8 of Set 16 | neuquen
# Processing Record 9 of Set 16 | maceio
# Processing Record 10 of Set 16 | kyren
# Processing Record 11 of Set 16 | ayagoz
# Processing Record 12 of Set 16 | sibu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Camacha  33.0833  -16.3333     63.82        88          40
# 1       Cherskiy  68.7500  161.3000     47.19        71         100
# 2       Saldanha -33.0117   17.9442     60.96        77          54
# 3    San Lorenzo -25.3333  -57.5333     49.59        76           0
# 4           Bara  10.3744   10.7288     86.23        49         100
# 5  Srednekolymsk  67.4500  153.6833     49.51        61          22
# 6           Lebu -37.6167  -73.6500     51.93        72          67
# 7         Albany  42.6001  -73.9662     58.39        82          47
# 8         Dikson  73.5069   80.5464     33.12       100         100
# 9     Bredasdorp -34.5322   20.0403     61.39        35          95
#
#    Wind Speed Country                 Date Current Description
# 0        5.75      PT  2022-05-17 03:24:01    scattered clouds
# 1       10.94      RU  2022-05-17 03:24:01     overcast clouds
# 2        4.23      ZA  2022-05-17 03:19:20       broken clouds
# 3        0.00      PY  2022-05-17 03:24:02           clear sky
# 4       10.65      NG  2022-05-17 03:24:02     overcast clouds
# 5        5.68      RU  2022-05-17 03:24:03          few clouds
# 6        3.98      CL  2022-05-17 03:24:03       broken clouds
# 7        1.01      US  2022-05-17 03:22:49    scattered clouds
# 8        3.98      RU  2022-05-17 03:24:04                snow
# 9        4.43      ZA  2022-05-17 03:24:04     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Camacha      PT  33.0833  -16.3333     63.82        88          40
# 1     Cherskiy      RU  68.7500  161.3000     47.19        71         100
# 2     Saldanha      ZA -33.0117   17.9442     60.96        77          54
# 3  San Lorenzo      PY -25.3333  -57.5333     49.59        76           0
# 4         Bara      NG  10.3744   10.7288     86.23        49         100
#
#    Wind Speed Current Description
# 0        5.75    scattered clouds
# 1       10.94     overcast clouds
# 2        4.23       broken clouds
# 3        0.00           clear sky
# 4       10.65     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
